# %%
import os
import config
import numpy as np
import soundfile as sf

# %%
#loopディレクトリにある各loop素材を8小節にして、lopop8mディレクトリに保存。
#def preprocess_loop():

    genras = os.listdir(f"loop\\")
    for genra in genras:
        bpm_keys = os.listdir(f"loop\\{genra}\\")
        for bpm_key in bpm_keys:
            parts = os.listdir(f"loop\\{genra}\\{bpm_key}")
            bpm = int(bpm_key[:3])
            for part in parts:
                insts = os.listdir(f"loop\\{genra}\\{bpm_key}\\{part}")
                for inst in insts:
                    os.makedirs(f"loop8m\\{genra}\\{bpm_key}\\{part}\\{inst}",exist_ok=True)
                    loops = os.listdir(f"loop\\{genra}\\{bpm_key}\\{part}\\{inst}")
                    for loop in loops:
                        loop_path   = f"loop\\{genra}\\{bpm_key}\\{part}\\{inst}\\{loop}"
                        output_path = f"loop8m\\{genra}\\{bpm_key}\\{part}\\{inst}\\{loop}"

                        print(f"loop_path = {loop_path}")
                        fit_loop_8bar(bpm, loop_path, output_path)
                    
                    #loop_bar_num = int(loop.split("_")[0][:2])
                    #repeat_num   = int(config.bar_num/loop_bar_num)
                    #repeat_loop(loop_path,output_path,repeat_num=repeat_num)
# Out:
# loop_path = loop\AcousticGuitar\080-A\Amelo\Guitar\02m_80bpm chord 1a 2m LF.wav
# data.shape[0] = 264600, bar8_sample = 1058400
# 0
# repeat_num = 4, data_frame.shape[0] = 264600, data.shape[0] = 264600
# loop_path = loop\AcousticGuitar\080-A\Amelo\Guitar\02m_80bpm chord 1b 2m LF.wav
# data.shape[0] = 264600, bar8_sample = 1058400
# 0
# repeat_num = 4, data_frame.shape[0] = 264600, data.shape[0] = 264600
# loop_path = loop\AcousticGuitar\080-A\Amelo\Guitar\04m_80bpm chord 1-6-4-1a 4m LF.wav
# data.shape[0] = 529200, bar8_sample = 1058400
# 0
# repeat_num = 2, data_frame.shape[0] = 529200, data.shape[0] = 529200
# loop_path = loop\AcousticGuitar\080-A\Amelo\Guitar\04m_80bpm chord 1c 4m LF.wav
# data.shape[0] = 529200, bar8_sample = 1058400
# 0
# repeat_num = 2, data_frame.shape[0] = 529200, data.shape[0] = 529200
# loop_path = loop\AcousticGuitar\080-A\Bmelo\Guitar\04m_80bpm chord 1-4-3-1-4-5a 4m LF.wav
# data.shape[0] = 529200, bar8_sample = 1058400
# 0
# repeat_num = 2, data_frame.shape[0] = 529200, data.shape[0] = 529200
# loop_path = loop\AcousticGuitar\080-A\Bmelo\Guitar\04m_80bpm chord 4-5-1-6-4-5-1 4m LF.wav
# data.shape[0] = 529200, bar8_sample = 1058400
# 0
# repeat_num = 2, data_frame.shape[0] = 529200, data.shape[0] = 529200
# loop_path = loop\AcousticGuitar\080-A\Bmelo\Guitar\04m_80bpm chord 4-7-4-5 4m LF.wav
# data.shape[0] = 529200, bar8_sample = 1058400
# 0
# repeat_num = 2, data_frame.shape[0] = 529200, data.shape[0] = 529200
# loop_path = loop\AcousticGuitar\080-A\Bmelo\Guitar\04m_80bpm chord 6-5-4a 4m LF.wav
# data.shape[0] = 529200, bar8_sample = 1058400
# 0
# repeat_num = 2, data_frame.shape[0] = 529200, data.shape[0] = 529200
# loop_path = loop\AcousticGuitar\080-A\Bmelo\Guitar\04m_80bpm chord 6-5-4b 4m LF.wav
# data.shape[0] = 529200, bar8_sample = 1058400
# 0
# repeat_num = 2, data_frame.shape[0] = 529200, data.shape[0] = 529200
# loop_path = loop\AcousticGuitar\080-A\Intro\Guitar\02m_80bpm arp 1a 2m LH.wav
# data.shape[0] = 264600, bar8_sample = 1058400
# 0
# repeat_num = 4, data_frame.shape[0] = 264600, data.shape[0] = 264600
# loop_path = loop\AcousticGuitar\080-A\Intro\Guitar\02m_80bpm arp 1b 2m LH.wav
# data.shape[0] = 264600, bar8_sample = 1058400
# 0
# repeat_num = 4, data_frame.shape[0] = 264600, data.shape[0] = 264600
# loop_path = loop\AcousticGuitar\080-A\Intro\Guitar\02m_80bpm arp 1c 2m LH.wav
# data.shape[0] = 264600, bar8_sample = 1058400
# 0
# repeat_num = 4, data_frame.shape[0] = 264600, data.shape[0] = 264600
# loop_path = loop\AcousticGuitar\080-A\Intro\Guitar\02m_80bpm arp 1d 2m LH.wav
# data.shape[0] = 264600, bar8_sample = 1058400
# 0
# repeat_num = 4, data_frame.shape[0] = 264600, data.shape[0] = 264600
# loop_path = loop\AcousticGuitar\080-A\Intro\Guitar\02m_80bpm arp 1e 2m LH.wav
# data.shape[0] = 264600, bar8_sample = 1058400
# 0
# repeat_num = 4, data_frame.shape[0] = 264600, data.shape[0] = 264600
# loop_path = loop\AcousticGuitar\080-A\Sabi\Guitar\02m_80bpm chord 3-4-1a 2m LF.wav
# data.shape[0] = 264600, bar8_sample = 1058400
# 0
# repeat_num = 4, data_frame.shape[0] = 264600, data.shape[0] = 264600
# loop_path = loop\AcousticGuitar\080-A\Sabi\Guitar\02m_80bpm chord 6-7-1a 2m LF.wav
# data.shape[0] = 264600, bar8_sample = 1058400
# 0
# repeat_num = 4, data_frame.shape[0] = 264600, data.shape[0] = 264600
# loop_path = loop\AcousticGuitar\080-A\Sabi\Guitar\04m_80bpm chord 1-6-4-1a 4m LF.wav
# data.shape[0] = 529200, bar8_sample = 1058400
# 0
# repeat_num = 2, data_frame.shape[0] = 529200, data.shape[0] = 529200
# loop_path = loop\AcousticGuitar\080-A\Sabi\Guitar\04m_80bpm chord 2-6-7-5-2-6-5-4 4m LF.wav
# data.shape[0] = 529200, bar8_sample = 1058400
# 0
# repeat_num = 2, data_frame.shape[0] = 529200, data.shape[0] = 529200
# loop_path = loop\AcousticGuitar\130-C\Amelo\Guitar\02m_04 Acoustic Guitar AG1 35 - 130 BPM - Am.wav
# data.shape[0] = 162831, bar8_sample = 651323
# -1
# repeat_num = 4, data_frame.shape[0] = 162830, data.shape[0] = 162831
# loop_path = loop\AcousticGuitar\130-C\Amelo\Guitar\04m_01 Acoustic Guitar AG1 35 - 130 BPM - C.wav
# data.shape[0] = 325662, bar8_sample = 651323
# -1
# repeat_num = 2, data_frame.shape[0] = 325661, data.shape[0] = 325662
# loop_path = loop\AcousticGuitar\130-C\Bmelo\Guitar\04m_02 Acoustic Guitar AG1 35 - 130 BPM - C.wav
# data.shape[0] = 325662, bar8_sample = 651323
# -1
# repeat_num = 2, data_frame.shape[0] = 325661, data.shape[0] = 325662
# loop_path = loop\AcousticGuitar\130-C\Bmelo\Guitar\08m_01 Acoustic Guitar AG1 34 - 130 BPM - Am.wav
# data.shape[0] = 651323, bar8_sample = 651323
# 0
# repeat_num = 1, data_frame.shape[0] = 651323, data.shape[0] = 651323
# loop_path = loop\AcousticGuitar\130-C\Bmelo\Guitar\08m_02 Acoustic Guitar AG1 34 - 130 BPM - Am.wav
# data.shape[0] = 651323, bar8_sample = 651323
# 0
# repeat_num = 1, data_frame.shape[0] = 651323, data.shape[0] = 651323
# loop_path = loop\AcousticGuitar\130-C\Intro\Guitar\04m_10 Acoustic Guitar AG1 35 - 130 BPM - Am.wav
# data.shape[0] = 325662, bar8_sample = 651323
# -1
# repeat_num = 2, data_frame.shape[0] = 325661, data.shape[0] = 325662
# loop_path = loop\AcousticGuitar\130-C\Intro\Guitar\04m_13 Acoustic Guitar AG1 35 - 130 BPM - C.wav
# data.shape[0] = 325662, bar8_sample = 651323
# -1
# repeat_num = 2, data_frame.shape[0] = 325661, data.shape[0] = 325662
# loop_path = loop\AcousticGuitar\130-C\Intro\Guitar\04m_15 Acoustic Guitar AG1 35 - 130 BPM - Am.wav
# data.shape[0] = 325662, bar8_sample = 651323
# -1
# repeat_num = 2, data_frame.shape[0] = 325661, data.shape[0] = 325662
# loop_path = loop\AcousticGuitar\130-C\Sabi\Guitar\02m_06 Acoustic Guitar AG1 35 - 130 BPM - C.wav
# data.shape[0] = 162831, bar8_sample = 651323
# -1
# repeat_num = 4, data_frame.shape[0] = 162830, data.shape[0] = 162831
# loop_path = loop\AcousticGuitar\130-C\Sabi\Guitar\04m_20 Acoustic Guitar AG1 35 - 130 BPM - Am.wav
# data.shape[0] = 325662, bar8_sample = 651323
# -1
# repeat_num = 2, data_frame.shape[0] = 325661, data.shape[0] = 325662
# loop_path = loop\AcousticGuitar\130-C\Sabi\Guitar\04m_22 Acoustic Guitar AG1 35 - 130 BPM - C.wav
# data.shape[0] = 325662, bar8_sample = 651323
# -1
# repeat_num = 2, data_frame.shape[0] = 325661, data.shape[0] = 325662
# loop_path = loop\AcousticGuitar\130-C\Sabi\Guitar\04m_23 Acoustic Guitar AG1 35 - 130 BPM - C.wav
# data.shape[0] = 325662, bar8_sample = 651323
# -1
# repeat_num = 2, data_frame.shape[0] = 325661, data.shape[0] = 325662
# loop_path = loop\EDM\154-F\Amelo\Bass\08m_IQ HCP - [Kit 06] Bass Loop 1 F0 154 BPM.wav
# data.shape[0] = 549819, bar8_sample = 549818
# loop_path = loop\EDM\154-F\Amelo\Bass\08m_IQ HCP - [Kit 06] Bass Loop 2 F0 154 BPM.wav
# data.shape[0] = 549819, bar8_sample = 549818
# loop_path = loop\EDM\154-F\Amelo\Fx\08m_IQ HCP - [Kit 06] FX Loop 1 154 BPM.wav
# data.shape[0] = 549819, bar8_sample = 549818
# loop_path = loop\EDM\154-F\Amelo\Guitar\08m_IQ HCP - [Kit 06] Guitar Loop 1 F2 154 BPM.wav
# data.shape[0] = 549819, bar8_sample = 549818
# loop_path = loop\EDM\154-F\Amelo\Guitar\08m_IQ HCP - [Kit 06] Guitar Loop 2 F2 154 BPM.wav
# data.shape[0] = 549819, bar8_sample = 549818
# loop_path = loop\EDM\154-F\Amelo\Marimba\08m_IQ HCP - [Kit 06] Marimba Loop 1 F3 154 BPM.wav
# data.shape[0] = 549819, bar8_sample = 549818
# loop_path = loop\EDM\154-F\Amelo\Marimba\08m_IQ HCP - [Kit 06] Marimba Loop 2 F3 154 BPM.wav
# data.shape[0] = 549819, bar8_sample = 549818
# loop_path = loop\EDM\154-F\Amelo\Marimba\08m_IQ HCP - [Kit 06] Marimba Loop 3 D2 154 BPM.wav
# data.shape[0] = 549819, bar8_sample = 549818
# loop_path = loop\EDM\154-F\Amelo\Rhythm\04m_IQ HCP - [Kit 06] Drum Loop 1 154 BPM.wav
# data.shape[0] = 274910, bar8_sample = 549818
# -1
# repeat_num = 2, data_frame.shape[0] = 274909, data.shape[0] = 274910
# loop_path = loop\EDM\154-F\Amelo\Rhythm\08m_IQ HCP - [Kit 06] Drum Loop 3 154 BPM.wav
# data.shape[0] = 549819, bar8_sample = 549818
# loop_path = loop\EDM\154-F\Bmelo\Bass\08m_IQ HCP - [Kit 06] Bass Loop 1 F0 154 BPM.wav
# data.shape[0] = 549819, bar8_sample = 549818
# loop_path = loop\EDM\154-F\Bmelo\Bass\08m_IQ HCP - [Kit 06] Bass Loop 2 F0 154 BPM.wav
# data.shape[0] = 549819, bar8_sample = 549818
# loop_path = loop\EDM\154-F\Bmelo\Fx\08m_IQ HCP - [Kit 06] FX Loop 1 154 BPM.wav
# data.shape[0] = 549819, bar8_sample = 549818
# loop_path = loop\EDM\154-F\Bmelo\Guitar\08m_IQ HCP - [Kit 06] Guitar Loop 1 F2 154 BPM.wav
# data.shape[0] = 549819, bar8_sample = 549818
# loop_path = loop\EDM\154-F\Bmelo\Guitar\08m_IQ HCP - [Kit 06] Guitar Loop 2 F2 154 BPM.wav
# data.shape[0] = 549819, bar8_sample = 549818
# loop_path = loop\EDM\154-F\Bmelo\Marimba\08m_IQ HCP - [Kit 06] Marimba Loop 1 F3 154 BPM.wav
# data.shape[0] = 549819, bar8_sample = 549818
# loop_path = loop\EDM\154-F\Bmelo\Marimba\08m_IQ HCP - [Kit 06] Marimba Loop 2 F3 154 BPM.wav
# data.shape[0] = 549819, bar8_sample = 549818
# loop_path = loop\EDM\154-F\Bmelo\Marimba\08m_IQ HCP - [Kit 06] Marimba Loop 3 D2 154 BPM.wav
# data.shape[0] = 549819, bar8_sample = 549818
# loop_path = loop\EDM\154-F\Bmelo\Rhythm\04m_IQ HCP - [Kit 06] Drum Loop 1 154 BPM.wav
# data.shape[0] = 274910, bar8_sample = 549818
# -1
# repeat_num = 2, data_frame.shape[0] = 274909, data.shape[0] = 274910
# loop_path = loop\EDM\154-F\Bmelo\Rhythm\08m_IQ HCP - [Kit 06] Drum Loop 1＆2 154 BPM.wav
# data.shape[0] = 550355, bar8_sample = 549818
# loop_path = loop\EDM\154-F\Intro\Fx\08m_IQ HCP - [Kit 06] FX Loop 1 154 BPM.wav
# data.shape[0] = 549819, bar8_sample = 549818
# loop_path = loop\EDM\154-F\Intro\Guitar\08m_IQ HCP - [Kit 06] Guitar Loop 1 F2 154 BPM.wav
# data.shape[0] = 549819, bar8_sample = 549818
# loop_path = loop\EDM\154-F\Intro\Marimba\08m_IQ HCP - [Kit 06] Marimba Loop 1 F3 154 BPM.wav
# data.shape[0] = 549819, bar8_sample = 549818
# loop_path = loop\EDM\154-F\Intro\Marimba\08m_IQ HCP - [Kit 06] Marimba Loop 2 F3 154 BPM.wav
# data.shape[0] = 549819, bar8_sample = 549818
# loop_path = loop\EDM\154-F\Sabi\Backing\04m_IQ HCP - [Kit 06] Chords Loop 1 D4 154 BPM.wav
# data.shape[0] = 137455, bar8_sample = 549818
# -1
# repeat_num = 4, data_frame.shape[0] = 137454, data.shape[0] = 137455
# loop_path = loop\EDM\154-F\Sabi\Backing\04m_IQ HCP - [Kit 06] Chords Loop 2 D4 154 BPM.wav
# data.shape[0] = 137455, bar8_sample = 549818
# -1
# repeat_num = 4, data_frame.shape[0] = 137454, data.shape[0] = 137455
# loop_path = loop\EDM\154-F\Sabi\Bass\08m_IQ HCP - [Kit 06] Bass Loop 1 F0 154 BPM.wav
# data.shape[0] = 549819, bar8_sample = 549818
# loop_path = loop\EDM\154-F\Sabi\Bass\08m_IQ HCP - [Kit 06] Bass Loop 2 F0 154 BPM.wav
# data.shape[0] = 549819, bar8_sample = 549818
# loop_path = loop\EDM\154-F\Sabi\Fx\08m_IQ HCP - [Kit 06] FX Loop 1 154 BPM.wav
# data.shape[0] = 549819, bar8_sample = 549818
# loop_path = loop\EDM\154-F\Sabi\Guitar\08m_IQ HCP - [Kit 06] Guitar Loop 1 F2 154 BPM.wav
# data.shape[0] = 549819, bar8_sample = 549818
# loop_path = loop\EDM\154-F\Sabi\Guitar\08m_IQ HCP - [Kit 06] Guitar Loop 2 F2 154 BPM.wav
# data.shape[0] = 549819, bar8_sample = 549818
# loop_path = loop\EDM\154-F\Sabi\Marimba\08m_IQ HCP - [Kit 06] Marimba Loop 1 F3 154 BPM.wav
# data.shape[0] = 549819, bar8_sample = 549818
# loop_path = loop\EDM\154-F\Sabi\Marimba\08m_IQ HCP - [Kit 06] Marimba Loop 2 F3 154 BPM.wav
# data.shape[0] = 549819, bar8_sample = 549818
# loop_path = loop\EDM\154-F\Sabi\Marimba\08m_IQ HCP - [Kit 06] Marimba Loop 3 D2 154 BPM.wav
# data.shape[0] = 549819, bar8_sample = 549818
# loop_path = loop\EDM\154-F\Sabi\Rhythm\08m_IQ HCP - [Kit 06] Drum Loop 3 154 BPM.wav
# data.shape[0] = 549819, bar8_sample = 549818
# loop_path = loop\EDM\155-D\Amelo\Bass\04m_IQ HCP - [Kit 04] Bass Loop 1 G1 155 BPM.wav
# data.shape[0] = 273136, bar8_sample = 546270
# -1
# repeat_num = 2, data_frame.shape[0] = 273135, data.shape[0] = 273136
# loop_path = loop\EDM\155-D\Amelo\Drum\01m_IQ HCP - [Kit 04] Drum Loop 1 155 BPM.wav
# data.shape[0] = 68284, bar8_sample = 546270
# -1
# repeat_num = 8, data_frame.shape[0] = 68283, data.shape[0] = 68284
# loop_path = loop\EDM\155-D\Amelo\Drum\01m_IQ HCP - [Kit 04] Drum Loop 2 155 BPM.wav
# data.shape[0] = 68284, bar8_sample = 546270
# -1
# repeat_num = 8, data_frame.shape[0] = 68283, data.shape[0] = 68284
# loop_path = loop\EDM\155-D\Amelo\Drum\08m_IQ HCP - [Kit 04] Drum Loop 3 155 BPM.wav
# data.shape[0] = 546271, bar8_sample = 546270
# loop_path = loop\EDM\155-D\Amelo\Flute\08m_IQ HCP - [Kit 04] Flute Loop 1 A3 155 BPM.wav
# data.shape[0] = 546271, bar8_sample = 546270
# loop_path = loop\EDM\155-D\Amelo\Flute\08m_IQ HCP - [Kit 04] Flute Loop 2 A3 155 BPM.wav
# data.shape[0] = 546271, bar8_sample = 546270
# loop_path = loop\EDM\155-D\Amelo\Flute\08m_IQ HCP - [Kit 04] Flute Loop 3 F#3 155 BPM.wav
# data.shape[0] = 546271, bar8_sample = 546270
# loop_path = loop\EDM\155-D\Amelo\Flute\08m_IQ HCP - [Kit 04] Flute Loop 4 E3 155 BPM.wav
# data.shape[0] = 546271, bar8_sample = 546270
# loop_path = loop\EDM\155-D\Amelo\Flute\08m_IQ HCP - [Kit 04] Flute Loop 5 D3 155 BPM.wav
# data.shape[0] = 546271, bar8_sample = 546270
# loop_path = loop\EDM\155-D\Amelo\Flute\08m_IQ HCP - [Kit 04] Flute Loop 6 D4 155 BPM.wav
# data.shape[0] = 546271, bar8_sample = 546270
# loop_path = loop\EDM\155-D\Amelo\Flute\08m_IQ HCP - [Kit 04] Flute Loop 7 A3 155 BPM.wav
# data.shape[0] = 546271, bar8_sample = 546270
# loop_path = loop\EDM\155-D\Amelo\GuitarMain\08m_IQ HCP - [Kit 04] Guitar Loop 1 G2 155 BPM.wav
# data.shape[0] = 546271, bar8_sample = 546270
# loop_path = loop\EDM\155-D\Amelo\GuitarMain\08m_IQ HCP - [Kit 04] Guitar Loop 2 G2 155 BPM.wav
# data.shape[0] = 546271, bar8_sample = 546270
# loop_path = loop\EDM\155-D\Amelo\GuitarSub\02m_IQ HCP - [Kit 04] Guitar Loop 3 A2 155 BPM.wav
# data.shape[0] = 136568, bar8_sample = 546270
# -1
# repeat_num = 4, data_frame.shape[0] = 136567, data.shape[0] = 136568
# loop_path = loop\EDM\155-D\Amelo\GuitarSub\02m_IQ HCP - [Kit 04] Guitar Loop 4 B1 155 BPM.wav
# data.shape[0] = 136568, bar8_sample = 546270
# -1
# repeat_num = 4, data_frame.shape[0] = 136567, data.shape[0] = 136568
# loop_path = loop\EDM\155-D\Amelo\GuitarSub\02m_IQ HCP - [Kit 04] Guitar Loop 5 A3 155 BPM.wav
# data.shape[0] = 136568, bar8_sample = 546270
# -1
# repeat_num = 4, data_frame.shape[0] = 136567, data.shape[0] = 136568
# loop_path = loop\EDM\155-D\Amelo\GuitarSub\02m_IQ HCP - [Kit 04] Guitar Loop 6 B3 155 BPM.wav
# data.shape[0] = 136568, bar8_sample = 546270
# -1
# repeat_num = 4, data_frame.shape[0] = 136567, data.shape[0] = 136568
# loop_path = loop\EDM\155-D\Amelo\GuitarSub\02m_IQ HCP - [Kit 04] Guitar Loop 7 A4 155 BPM.wav
# data.shape[0] = 136568, bar8_sample = 546270
# -1
# repeat_num = 4, data_frame.shape[0] = 136567, data.shape[0] = 136568
# loop_path = loop\EDM\155-D\Amelo\GuitarSub\02m_IQ HCP - [Kit 04] Guitar Loop 8 B4 155 BPM.wav
# data.shape[0] = 136568, bar8_sample = 546270
# -1
# repeat_num = 4, data_frame.shape[0] = 136567, data.shape[0] = 136568
# loop_path = loop\EDM\155-D\Amelo\Mallets\08m_IQ HCP - [Kit 04] Mallets Loop 1 A3 155 BPM.wav
# data.shape[0] = 546271, bar8_sample = 546270
# loop_path = loop\EDM\155-D\Bmelo\Bass\04m_IQ HCP - [Kit 04] Bass Loop 1 G1 155 BPM.wav
# data.shape[0] = 273136, bar8_sample = 546270
# -1
# repeat_num = 2, data_frame.shape[0] = 273135, data.shape[0] = 273136
# loop_path = loop\EDM\155-D\Bmelo\Drum\01m_IQ HCP - [Kit 04] Drum Loop 1 155 BPM.wav
# data.shape[0] = 68284, bar8_sample = 546270
# -1
# repeat_num = 8, data_frame.shape[0] = 68283, data.shape[0] = 68284
# loop_path = loop\EDM\155-D\Bmelo\Drum\01m_IQ HCP - [Kit 04] Drum Loop 2 155 BPM.wav
# data.shape[0] = 68284, bar8_sample = 546270
# -1
# repeat_num = 8, data_frame.shape[0] = 68283, data.shape[0] = 68284
# loop_path = loop\EDM\155-D\Bmelo\Drum\08m_IQ HCP - [Kit 04] Drum Loop 3 155 BPM.wav
# data.shape[0] = 546271, bar8_sample = 546270
# loop_path = loop\EDM\155-D\Bmelo\Flute\08m_IQ HCP - [Kit 04] Flute Loop 1 A3 155 BPM.wav
# data.shape[0] = 546271, bar8_sample = 546270
# loop_path = loop\EDM\155-D\Bmelo\Flute\08m_IQ HCP - [Kit 04] Flute Loop 2 A3 155 BPM.wav
# data.shape[0] = 546271, bar8_sample = 546270
# loop_path = loop\EDM\155-D\Bmelo\Flute\08m_IQ HCP - [Kit 04] Flute Loop 3 F#3 155 BPM.wav
# data.shape[0] = 546271, bar8_sample = 546270
# loop_path = loop\EDM\155-D\Bmelo\Flute\08m_IQ HCP - [Kit 04] Flute Loop 4 E3 155 BPM.wav
# data.shape[0] = 546271, bar8_sample = 546270
# loop_path = loop\EDM\155-D\Bmelo\Flute\08m_IQ HCP - [Kit 04] Flute Loop 5 D3 155 BPM.wav
# data.shape[0] = 546271, bar8_sample = 546270
# loop_path = loop\EDM\155-D\Bmelo\Flute\08m_IQ HCP - [Kit 04] Flute Loop 6 D4 155 BPM.wav
# data.shape[0] = 546271, bar8_sample = 546270
# loop_path = loop\EDM\155-D\Bmelo\Flute\08m_IQ HCP - [Kit 04] Flute Loop 7 A3 155 BPM.wav
# data.shape[0] = 546271, bar8_sample = 546270
# loop_path = loop\EDM\155-D\Bmelo\GuitarMain\08m_IQ HCP - [Kit 04] Guitar Loop 1 G2 155 BPM.wav
# data.shape[0] = 546271, bar8_sample = 546270
# loop_path = loop\EDM\155-D\Bmelo\GuitarMain\08m_IQ HCP - [Kit 04] Guitar Loop 2 G2 155 BPM.wav
# data.shape[0] = 546271, bar8_sample = 546270
# loop_path = loop\EDM\155-D\Bmelo\GuitarSub\02m_IQ HCP - [Kit 04] Guitar Loop 3 A2 155 BPM.wav
# data.shape[0] = 136568, bar8_sample = 546270
# -1
# repeat_num = 4, data_frame.shape[0] = 136567, data.shape[0] = 136568
# loop_path = loop\EDM\155-D\Bmelo\GuitarSub\02m_IQ HCP - [Kit 04] Guitar Loop 4 B1 155 BPM.wav
# data.shape[0] = 136568, bar8_sample = 546270
# -1
# repeat_num = 4, data_frame.shape[0] = 136567, data.shape[0] = 136568
# loop_path = loop\EDM\155-D\Bmelo\GuitarSub\02m_IQ HCP - [Kit 04] Guitar Loop 5 A3 155 BPM.wav
# data.shape[0] = 136568, bar8_sample = 546270
# -1
# repeat_num = 4, data_frame.shape[0] = 136567, data.shape[0] = 136568
# loop_path = loop\EDM\155-D\Bmelo\GuitarSub\02m_IQ HCP - [Kit 04] Guitar Loop 6 B3 155 BPM.wav
# data.shape[0] = 136568, bar8_sample = 546270
# -1
# repeat_num = 4, data_frame.shape[0] = 136567, data.shape[0] = 136568
# loop_path = loop\EDM\155-D\Bmelo\GuitarSub\02m_IQ HCP - [Kit 04] Guitar Loop 7 A4 155 BPM.wav
# data.shape[0] = 136568, bar8_sample = 546270
# -1
# repeat_num = 4, data_frame.shape[0] = 136567, data.shape[0] = 136568
# loop_path = loop\EDM\155-D\Bmelo\GuitarSub\02m_IQ HCP - [Kit 04] Guitar Loop 8 B4 155 BPM.wav
# data.shape[0] = 136568, bar8_sample = 546270
# -1
# repeat_num = 4, data_frame.shape[0] = 136567, data.shape[0] = 136568
# loop_path = loop\EDM\155-D\Bmelo\Mallets\08m_IQ HCP - [Kit 04] Mallets Loop 1 A3 155 BPM.wav
# data.shape[0] = 546271, bar8_sample = 546270
# loop_path = loop\EDM\155-D\Intro\Drum\01m_IQ HCP - [Kit 04] Drum Loop 1 155 BPM.wav
# data.shape[0] = 68284, bar8_sample = 546270
# -1
# repeat_num = 8, data_frame.shape[0] = 68283, data.shape[0] = 68284
# loop_path = loop\EDM\155-D\Intro\Drum\01m_IQ HCP - [Kit 04] Drum Loop 2 155 BPM.wav
# data.shape[0] = 68284, bar8_sample = 546270
# -1
# repeat_num = 8, data_frame.shape[0] = 68283, data.shape[0] = 68284
# loop_path = loop\EDM\155-D\Intro\Flute\08m_IQ HCP - [Kit 04] Flute Loop 1 A3 155 BPM.wav
# data.shape[0] = 546271, bar8_sample = 546270
# loop_path = loop\EDM\155-D\Intro\Flute\08m_IQ HCP - [Kit 04] Flute Loop 2 A3 155 BPM.wav
# data.shape[0] = 546271, bar8_sample = 546270
# loop_path = loop\EDM\155-D\Intro\Flute\08m_IQ HCP - [Kit 04] Flute Loop 3 F#3 155 BPM.wav
# data.shape[0] = 546271, bar8_sample = 546270
# loop_path = loop\EDM\155-D\Intro\Flute\08m_IQ HCP - [Kit 04] Flute Loop 4 E3 155 BPM.wav
# data.shape[0] = 546271, bar8_sample = 546270
# loop_path = loop\EDM\155-D\Intro\Flute\08m_IQ HCP - [Kit 04] Flute Loop 5 D3 155 BPM.wav
# data.shape[0] = 546271, bar8_sample = 546270
# loop_path = loop\EDM\155-D\Intro\Flute\08m_IQ HCP - [Kit 04] Flute Loop 6 D4 155 BPM.wav
# data.shape[0] = 546271, bar8_sample = 546270
# loop_path = loop\EDM\155-D\Intro\Flute\08m_IQ HCP - [Kit 04] Flute Loop 7 A3 155 BPM.wav
# data.shape[0] = 546271, bar8_sample = 546270
# loop_path = loop\EDM\155-D\Intro\GuitarMain\08m_IQ HCP - [Kit 04] Guitar Loop 1 G2 155 BPM.wav
# data.shape[0] = 546271, bar8_sample = 546270
# loop_path = loop\EDM\155-D\Intro\GuitarMain\08m_IQ HCP - [Kit 04] Guitar Loop 2 G2 155 BPM.wav
# data.shape[0] = 546271, bar8_sample = 546270
# loop_path = loop\EDM\155-D\Intro\Mallets\08m_IQ HCP - [Kit 04] Mallets Loop 1 A3 155 BPM.wav
# data.shape[0] = 546271, bar8_sample = 546270
# loop_path = loop\EDM\155-D\Sabi\Bass\04m_IQ HCP - [Kit 04] Bass Loop 1 G1 155 BPM.wav
# data.shape[0] = 273136, bar8_sample = 546270
# -1
# repeat_num = 2, data_frame.shape[0] = 273135, data.shape[0] = 273136
# loop_path = loop\EDM\155-D\Sabi\Drum\01m_IQ HCP - [Kit 04] Drum Loop 1 155 BPM.wav
# data.shape[0] = 68284, bar8_sample = 546270
# -1
# repeat_num = 8, data_frame.shape[0] = 68283, data.shape[0] = 68284
# loop_path = loop\EDM\155-D\Sabi\Drum\01m_IQ HCP - [Kit 04] Drum Loop 2 155 BPM.wav
# data.shape[0] = 68284, bar8_sample = 546270
# -1
# repeat_num = 8, data_frame.shape[0] = 68283, data.shape[0] = 68284
# loop_path = loop\EDM\155-D\Sabi\Drum\08m_IQ HCP - [Kit 04] Drum Loop 3 155 BPM.wav
# data.shape[0] = 546271, bar8_sample = 546270
# loop_path = loop\EDM\155-D\Sabi\Flute\08m_IQ HCP - [Kit 04] Flute Loop 1 A3 155 BPM.wav
# data.shape[0] = 546271, bar8_sample = 546270
# loop_path = loop\EDM\155-D\Sabi\Flute\08m_IQ HCP - [Kit 04] Flute Loop 2 A3 155 BPM.wav
# data.shape[0] = 546271, bar8_sample = 546270
# loop_path = loop\EDM\155-D\Sabi\Flute\08m_IQ HCP - [Kit 04] Flute Loop 3 F#3 155 BPM.wav
# data.shape[0] = 546271, bar8_sample = 546270
# loop_path = loop\EDM\155-D\Sabi\Flute\08m_IQ HCP - [Kit 04] Flute Loop 4 E3 155 BPM.wav
# data.shape[0] = 546271, bar8_sample = 546270
# loop_path = loop\EDM\155-D\Sabi\Flute\08m_IQ HCP - [Kit 04] Flute Loop 5 D3 155 BPM.wav
# data.shape[0] = 546271, bar8_sample = 546270
# loop_path = loop\EDM\155-D\Sabi\Flute\08m_IQ HCP - [Kit 04] Flute Loop 6 D4 155 BPM.wav
# data.shape[0] = 546271, bar8_sample = 546270
# loop_path = loop\EDM\155-D\Sabi\Flute\08m_IQ HCP - [Kit 04] Flute Loop 7 A3 155 BPM.wav
# data.shape[0] = 546271, bar8_sample = 546270
# loop_path = loop\EDM\155-D\Sabi\GuitarMain\08m_IQ HCP - [Kit 04] Guitar Loop 1 G2 155 BPM.wav
# data.shape[0] = 546271, bar8_sample = 546270
# loop_path = loop\EDM\155-D\Sabi\GuitarMain\08m_IQ HCP - [Kit 04] Guitar Loop 2 G2 155 BPM.wav
# data.shape[0] = 546271, bar8_sample = 546270
# loop_path = loop\EDM\155-D\Sabi\GuitarSub\02m_IQ HCP - [Kit 04] Guitar Loop 3 A2 155 BPM.wav
# data.shape[0] = 136568, bar8_sample = 546270
# -1
# repeat_num = 4, data_frame.shape[0] = 136567, data.shape[0] = 136568
# loop_path = loop\EDM\155-D\Sabi\GuitarSub\02m_IQ HCP - [Kit 04] Guitar Loop 4 B1 155 BPM.wav
# data.shape[0] = 136568, bar8_sample = 546270
# -1
# repeat_num = 4, data_frame.shape[0] = 136567, data.shape[0] = 136568
# loop_path = loop\EDM\155-D\Sabi\GuitarSub\02m_IQ HCP - [Kit 04] Guitar Loop 5 A3 155 BPM.wav
# data.shape[0] = 136568, bar8_sample = 546270
# -1
# repeat_num = 4, data_frame.shape[0] = 136567, data.shape[0] = 136568
# loop_path = loop\EDM\155-D\Sabi\GuitarSub\02m_IQ HCP - [Kit 04] Guitar Loop 6 B3 155 BPM.wav
# data.shape[0] = 136568, bar8_sample = 546270
# -1
# repeat_num = 4, data_frame.shape[0] = 136567, data.shape[0] = 136568
# loop_path = loop\EDM\155-D\Sabi\GuitarSub\02m_IQ HCP - [Kit 04] Guitar Loop 7 A4 155 BPM.wav
# data.shape[0] = 136568, bar8_sample = 546270
# -1
# repeat_num = 4, data_frame.shape[0] = 136567, data.shape[0] = 136568
# loop_path = loop\EDM\155-D\Sabi\GuitarSub\02m_IQ HCP - [Kit 04] Guitar Loop 8 B4 155 BPM.wav
# data.shape[0] = 136568, bar8_sample = 546270
# -1
# repeat_num = 4, data_frame.shape[0] = 136567, data.shape[0] = 136568
# loop_path = loop\EDM\155-D\Sabi\Mallets\08m_IQ HCP - [Kit 04] Mallets Loop 1 A3 155 BPM.wav
# data.shape[0] = 546271, bar8_sample = 546270
# loop_path = loop\Metal\105-D\Amelo\Bass\04m_IQ HCP - [Kit 05] Bass Loop 1 D1 105 BPM.wav
# data.shape[0] = 364966, bar8_sample = 806400
# 38234
# repeat_num = 2, data_frame.shape[0] = 403200, data.shape[0] = 364966
# loop_path = loop\Metal\105-D\Amelo\Bass\04m_IQ HCP - [Kit 05] Bass Loop 2 D1 105 BPM.wav
# data.shape[0] = 364966, bar8_sample = 806400
# 38234
# repeat_num = 2, data_frame.shape[0] = 403200, data.shape[0] = 364966
# loop_path = loop\Metal\105-D\Amelo\Drum\04m_IQ HCP - [Kit 05] Drum Loop 1 105 BPM.wav
# data.shape[0] = 403200, bar8_sample = 806400
# 0
# repeat_num = 2, data_frame.shape[0] = 403200, data.shape[0] = 403200
# loop_path = loop\Metal\105-D\Amelo\Drum\04m_IQ HCP - [Kit 05] Drum Loop 2 105 BPM.wav
# data.shape[0] = 403200, bar8_sample = 806400
# 0
# repeat_num = 2, data_frame.shape[0] = 403200, data.shape[0] = 403200
# loop_path = loop\Metal\105-D\Amelo\GuitarMain\02m_IQ HCP - [Kit 05] Guitar Loop 7 D1 105 BPM.wav
# data.shape[0] = 201600, bar8_sample = 806400
# 0
# repeat_num = 4, data_frame.shape[0] = 201600, data.shape[0] = 201600
# loop_path = loop\Metal\105-D\Amelo\GuitarMain\04m_IQ HCP - [Kit 05] Guitar Loop 1 D1 105 BPM.wav
# data.shape[0] = 403200, bar8_sample = 806400
# 0
# repeat_num = 2, data_frame.shape[0] = 403200, data.shape[0] = 403200
# loop_path = loop\Metal\105-D\Amelo\GuitarMain\04m_IQ HCP - [Kit 05] Guitar Loop 2 D0 105 BPM.wav
# data.shape[0] = 403200, bar8_sample = 806400
# 0
# repeat_num = 2, data_frame.shape[0] = 403200, data.shape[0] = 403200
# loop_path = loop\Metal\105-D\Amelo\GuitarMain\04m_IQ HCP - [Kit 05] Guitar Loop 3 D3 105 BPM.wav
# data.shape[0] = 403200, bar8_sample = 806400
# 0
# repeat_num = 2, data_frame.shape[0] = 403200, data.shape[0] = 403200
# loop_path = loop\Metal\105-D\Amelo\GuitarMain\04m_IQ HCP - [Kit 05] Guitar Loop 4 D3 105 BPM.wav
# data.shape[0] = 403200, bar8_sample = 806400
# 0
# repeat_num = 2, data_frame.shape[0] = 403200, data.shape[0] = 403200
# loop_path = loop\Metal\105-D\Amelo\GuitarMain\04m_IQ HCP - [Kit 05] Guitar Loop 5 D3 105 BPM.wav
# data.shape[0] = 403200, bar8_sample = 806400
# 0
# repeat_num = 2, data_frame.shape[0] = 403200, data.shape[0] = 403200
# loop_path = loop\Metal\105-D\Amelo\GuitarMain\04m_IQ HCP - [Kit 05] Guitar Loop 6 D1 105 BPM.wav
# data.shape[0] = 403200, bar8_sample = 806400
# 0
# repeat_num = 2, data_frame.shape[0] = 403200, data.shape[0] = 403200
# loop_path = loop\Metal\105-D\Amelo\GuitarMain\04m_IQ HCP - [Kit 05] Guitar Loop 8 D1 105 BPM.wav
# data.shape[0] = 403200, bar8_sample = 806400
# 0
# repeat_num = 2, data_frame.shape[0] = 403200, data.shape[0] = 403200
# loop_path = loop\Metal\105-D\Amelo\GuitarMain\04m_IQ HCP - [Kit 05] Guitar Loop 9 D1 105 BPM.wav
# data.shape[0] = 403200, bar8_sample = 806400
# 0
# repeat_num = 2, data_frame.shape[0] = 403200, data.shape[0] = 403200
# loop_path = loop\Metal\105-D\Amelo\GuitarSub\02m_IQ HCP - [Kit 05] Guitar Loop 7 D1 105 BPM.wav
# data.shape[0] = 201600, bar8_sample = 806400
# 0
# repeat_num = 4, data_frame.shape[0] = 201600, data.shape[0] = 201600
# loop_path = loop\Metal\105-D\Amelo\GuitarSub\04m_IQ HCP - [Kit 05] Guitar Loop 1 D1 105 BPM.wav
# data.shape[0] = 403200, bar8_sample = 806400
# 0
# repeat_num = 2, data_frame.shape[0] = 403200, data.shape[0] = 403200
# loop_path = loop\Metal\105-D\Amelo\GuitarSub\04m_IQ HCP - [Kit 05] Guitar Loop 2 D0 105 BPM.wav
# data.shape[0] = 403200, bar8_sample = 806400
# 0
# repeat_num = 2, data_frame.shape[0] = 403200, data.shape[0] = 403200
# loop_path = loop\Metal\105-D\Amelo\GuitarSub\04m_IQ HCP - [Kit 05] Guitar Loop 3 D3 105 BPM.wav
# data.shape[0] = 403200, bar8_sample = 806400
# 0
# repeat_num = 2, data_frame.shape[0] = 403200, data.shape[0] = 403200
# loop_path = loop\Metal\105-D\Amelo\GuitarSub\04m_IQ HCP - [Kit 05] Guitar Loop 4 D3 105 BPM.wav
# data.shape[0] = 403200, bar8_sample = 806400
# 0
# repeat_num = 2, data_frame.shape[0] = 403200, data.shape[0] = 403200
# loop_path = loop\Metal\105-D\Amelo\GuitarSub\04m_IQ HCP - [Kit 05] Guitar Loop 5 D3 105 BPM.wav
# data.shape[0] = 403200, bar8_sample = 806400
# 0
# repeat_num = 2, data_frame.shape[0] = 403200, data.shape[0] = 403200
# loop_path = loop\Metal\105-D\Amelo\GuitarSub\04m_IQ HCP - [Kit 05] Guitar Loop 6 D1 105 BPM.wav
# data.shape[0] = 403200, bar8_sample = 806400
# 0
# repeat_num = 2, data_frame.shape[0] = 403200, data.shape[0] = 403200
# loop_path = loop\Metal\105-D\Amelo\GuitarSub\04m_IQ HCP - [Kit 05] Guitar Loop 8 D1 105 BPM.wav
# data.shape[0] = 403200, bar8_sample = 806400
# 0
# repeat_num = 2, data_frame.shape[0] = 403200, data.shape[0] = 403200
# loop_path = loop\Metal\105-D\Amelo\GuitarSub\04m_IQ HCP - [Kit 05] Guitar Loop 9 D1 105 BPM.wav
# data.shape[0] = 403200, bar8_sample = 806400
# 0
# repeat_num = 2, data_frame.shape[0] = 403200, data.shape[0] = 403200
# loop_path = loop\Metal\105-D\Bmelo\Bass\08m_IQ HCP - [Kit 05] Bass Loop 1 D1 105 BPM.wav
# data.shape[0] = 364966, bar8_sample = 806400
# 38234
# repeat_num = 2, data_frame.shape[0] = 403200, data.shape[0] = 364966
# loop_path = loop\Metal\105-D\Bmelo\Bass\08m_IQ HCP - [Kit 05] Bass Loop 2 D1 105 BPM.wav
# data.shape[0] = 364966, bar8_sample = 806400
# 38234
# repeat_num = 2, data_frame.shape[0] = 403200, data.shape[0] = 364966
# loop_path = loop\Metal\105-D\Bmelo\Drum\08m_IQ HCP - [Kit 05] Drum Loop 2 105 BPM.wav
# data.shape[0] = 403200, bar8_sample = 806400
# 0
# repeat_num = 2, data_frame.shape[0] = 403200, data.shape[0] = 403200
# loop_path = loop\Metal\105-D\Bmelo\Drum\08m_IQ HCP - [Kit 05] Drum Loop 3 105 BPM.wav
# data.shape[0] = 403200, bar8_sample = 806400
# 0
# repeat_num = 2, data_frame.shape[0] = 403200, data.shape[0] = 403200
# loop_path = loop\Metal\105-D\Bmelo\Drum\08m_IQ HCP - [Kit 05] Drum Loop 4 105 BPM.wav
# data.shape[0] = 403200, bar8_sample = 806400
# 0
# repeat_num = 2, data_frame.shape[0] = 403200, data.shape[0] = 403200
# loop_path = loop\Metal\105-D\Bmelo\GuitarMain\04m_IQ HCP - [Kit 05] Guitar Loop 7 D1 105 BPM.wav
# data.shape[0] = 201600, bar8_sample = 806400
# 0
# repeat_num = 4, data_frame.shape[0] = 201600, data.shape[0] = 201600
# loop_path = loop\Metal\105-D\Bmelo\GuitarMain\08m_IQ HCP - [Kit 05] Guitar Loop 1 D1 105 BPM.wav
# data.shape[0] = 403200, bar8_sample = 806400
# 0
# repeat_num = 2, data_frame.shape[0] = 403200, data.shape[0] = 403200
# loop_path = loop\Metal\105-D\Bmelo\GuitarMain\08m_IQ HCP - [Kit 05] Guitar Loop 2 D0 105 BPM.wav
# data.shape[0] = 403200, bar8_sample = 806400
# 0
# repeat_num = 2, data_frame.shape[0] = 403200, data.shape[0] = 403200
# loop_path = loop\Metal\105-D\Bmelo\GuitarMain\08m_IQ HCP - [Kit 05] Guitar Loop 3 D3 105 BPM.wav
# data.shape[0] = 403200, bar8_sample = 806400
# 0
# repeat_num = 2, data_frame.shape[0] = 403200, data.shape[0] = 403200
# loop_path = loop\Metal\105-D\Bmelo\GuitarMain\08m_IQ HCP - [Kit 05] Guitar Loop 4 D3 105 BPM.wav
# data.shape[0] = 403200, bar8_sample = 806400
# 0
# repeat_num = 2, data_frame.shape[0] = 403200, data.shape[0] = 403200
# loop_path = loop\Metal\105-D\Bmelo\GuitarMain\08m_IQ HCP - [Kit 05] Guitar Loop 5 D3 105 BPM.wav
# data.shape[0] = 403200, bar8_sample = 806400
# 0
# repeat_num = 2, data_frame.shape[0] = 403200, data.shape[0] = 403200
# loop_path = loop\Metal\105-D\Bmelo\GuitarMain\08m_IQ HCP - [Kit 05] Guitar Loop 6 D1 105 BPM.wav
# data.shape[0] = 403200, bar8_sample = 806400
# 0
# repeat_num = 2, data_frame.shape[0] = 403200, data.shape[0] = 403200
# loop_path = loop\Metal\105-D\Bmelo\GuitarMain\08m_IQ HCP - [Kit 05] Guitar Loop 8 D1 105 BPM.wav
# data.shape[0] = 403200, bar8_sample = 806400
# 0
# repeat_num = 2, data_frame.shape[0] = 403200, data.shape[0] = 403200
# loop_path = loop\Metal\105-D\Bmelo\GuitarMain\08m_IQ HCP - [Kit 05] Guitar Loop 9 D1 105 BPM.wav
# data.shape[0] = 403200, bar8_sample = 806400
# 0
# repeat_num = 2, data_frame.shape[0] = 403200, data.shape[0] = 403200
# loop_path = loop\Metal\105-D\Bmelo\GuitarSub\04m_IQ HCP - [Kit 05] Guitar Loop 7 D1 105 BPM.wav
# data.shape[0] = 201600, bar8_sample = 806400
# 0
# repeat_num = 4, data_frame.shape[0] = 201600, data.shape[0] = 201600
# loop_path = loop\Metal\105-D\Bmelo\GuitarSub\08m_IQ HCP - [Kit 05] Guitar Loop 1 D1 105 BPM.wav
# data.shape[0] = 403200, bar8_sample = 806400
# 0
# repeat_num = 2, data_frame.shape[0] = 403200, data.shape[0] = 403200
# loop_path = loop\Metal\105-D\Bmelo\GuitarSub\08m_IQ HCP - [Kit 05] Guitar Loop 2 D0 105 BPM.wav
# data.shape[0] = 403200, bar8_sample = 806400
# 0
# repeat_num = 2, data_frame.shape[0] = 403200, data.shape[0] = 403200
# loop_path = loop\Metal\105-D\Bmelo\GuitarSub\08m_IQ HCP - [Kit 05] Guitar Loop 3 D3 105 BPM.wav
# data.shape[0] = 403200, bar8_sample = 806400
# 0
# repeat_num = 2, data_frame.shape[0] = 403200, data.shape[0] = 403200
# loop_path = loop\Metal\105-D\Bmelo\GuitarSub\08m_IQ HCP - [Kit 05] Guitar Loop 4 D3 105 BPM.wav
# data.shape[0] = 403200, bar8_sample = 806400
# 0
# repeat_num = 2, data_frame.shape[0] = 403200, data.shape[0] = 403200
# loop_path = loop\Metal\105-D\Bmelo\GuitarSub\08m_IQ HCP - [Kit 05] Guitar Loop 5 D3 105 BPM.wav
# data.shape[0] = 403200, bar8_sample = 806400
# 0
# repeat_num = 2, data_frame.shape[0] = 403200, data.shape[0] = 403200
# loop_path = loop\Metal\105-D\Bmelo\GuitarSub\08m_IQ HCP - [Kit 05] Guitar Loop 6 D1 105 BPM.wav
# data.shape[0] = 403200, bar8_sample = 806400
# 0
# repeat_num = 2, data_frame.shape[0] = 403200, data.shape[0] = 403200
# loop_path = loop\Metal\105-D\Bmelo\GuitarSub\08m_IQ HCP - [Kit 05] Guitar Loop 8 D1 105 BPM.wav
# data.shape[0] = 403200, bar8_sample = 806400
# 0
# repeat_num = 2, data_frame.shape[0] = 403200, data.shape[0] = 403200
# loop_path = loop\Metal\105-D\Bmelo\GuitarSub\08m_IQ HCP - [Kit 05] Guitar Loop 9 D1 105 BPM.wav
# data.shape[0] = 403200, bar8_sample = 806400
# 0
# repeat_num = 2, data_frame.shape[0] = 403200, data.shape[0] = 403200
# loop_path = loop\Metal\105-D\Intro\Bass\08m_IQ HCP - [Kit 05] Bass Loop 1 D1 105 BPM.wav
# data.shape[0] = 364966, bar8_sample = 806400
# 38234
# repeat_num = 2, data_frame.shape[0] = 403200, data.shape[0] = 364966
# loop_path = loop\Metal\105-D\Intro\Bass\08m_IQ HCP - [Kit 05] Bass Loop 2 D1 105 BPM.wav
# data.shape[0] = 364966, bar8_sample = 806400
# 38234
# repeat_num = 2, data_frame.shape[0] = 403200, data.shape[0] = 364966
# loop_path = loop\Metal\105-D\Intro\GuitarMain\04m_IQ HCP - [Kit 05] Guitar Loop 7 D1 105 BPM.wav
# data.shape[0] = 201600, bar8_sample = 806400
# 0
# repeat_num = 4, data_frame.shape[0] = 201600, data.shape[0] = 201600
# loop_path = loop\Metal\105-D\Intro\GuitarMain\08m_IQ HCP - [Kit 05] Guitar Loop 1 D1 105 BPM.wav
# data.shape[0] = 403200, bar8_sample = 806400
# 0
# repeat_num = 2, data_frame.shape[0] = 403200, data.shape[0] = 403200
# loop_path = loop\Metal\105-D\Intro\GuitarMain\08m_IQ HCP - [Kit 05] Guitar Loop 2 D0 105 BPM.wav
# data.shape[0] = 403200, bar8_sample = 806400
# 0
# repeat_num = 2, data_frame.shape[0] = 403200, data.shape[0] = 403200
# loop_path = loop\Metal\105-D\Intro\GuitarMain\08m_IQ HCP - [Kit 05] Guitar Loop 3 D3 105 BPM.wav
# data.shape[0] = 403200, bar8_sample = 806400
# 0
# repeat_num = 2, data_frame.shape[0] = 403200, data.shape[0] = 403200
# loop_path = loop\Metal\105-D\Intro\GuitarMain\08m_IQ HCP - [Kit 05] Guitar Loop 4 D3 105 BPM.wav
# data.shape[0] = 403200, bar8_sample = 806400
# 0
# repeat_num = 2, data_frame.shape[0] = 403200, data.shape[0] = 403200
# loop_path = loop\Metal\105-D\Intro\GuitarMain\08m_IQ HCP - [Kit 05] Guitar Loop 5 D3 105 BPM.wav
# data.shape[0] = 403200, bar8_sample = 806400
# 0
# repeat_num = 2, data_frame.shape[0] = 403200, data.shape[0] = 403200
# loop_path = loop\Metal\105-D\Intro\GuitarMain\08m_IQ HCP - [Kit 05] Guitar Loop 6 D1 105 BPM.wav
# data.shape[0] = 403200, bar8_sample = 806400
# 0
# repeat_num = 2, data_frame.shape[0] = 403200, data.shape[0] = 403200
# loop_path = loop\Metal\105-D\Intro\GuitarMain\08m_IQ HCP - [Kit 05] Guitar Loop 8 D1 105 BPM.wav
# data.shape[0] = 403200, bar8_sample = 806400
# 0
# repeat_num = 2, data_frame.shape[0] = 403200, data.shape[0] = 403200
# loop_path = loop\Metal\105-D\Intro\GuitarMain\08m_IQ HCP - [Kit 05] Guitar Loop 9 D1 105 BPM.wav
# data.shape[0] = 403200, bar8_sample = 806400
# 0
# repeat_num = 2, data_frame.shape[0] = 403200, data.shape[0] = 403200
# loop_path = loop\Metal\105-D\Intro\GuitarSub\04m_IQ HCP - [Kit 05] Guitar Loop 7 D1 105 BPM.wav
# data.shape[0] = 201600, bar8_sample = 806400
# 0
# repeat_num = 4, data_frame.shape[0] = 201600, data.shape[0] = 201600
# loop_path = loop\Metal\105-D\Intro\GuitarSub\08m_IQ HCP - [Kit 05] Guitar Loop 1 D1 105 BPM.wav
# data.shape[0] = 403200, bar8_sample = 806400
# 0
# repeat_num = 2, data_frame.shape[0] = 403200, data.shape[0] = 403200
# loop_path = loop\Metal\105-D\Intro\GuitarSub\08m_IQ HCP - [Kit 05] Guitar Loop 2 D0 105 BPM.wav
# data.shape[0] = 403200, bar8_sample = 806400
# 0
# repeat_num = 2, data_frame.shape[0] = 403200, data.shape[0] = 403200
# loop_path = loop\Metal\105-D\Intro\GuitarSub\08m_IQ HCP - [Kit 05] Guitar Loop 3 D3 105 BPM.wav
# data.shape[0] = 403200, bar8_sample = 806400
# 0
# repeat_num = 2, data_frame.shape[0] = 403200, data.shape[0] = 403200
# loop_path = loop\Metal\105-D\Intro\GuitarSub\08m_IQ HCP - [Kit 05] Guitar Loop 4 D3 105 BPM.wav
# data.shape[0] = 403200, bar8_sample = 806400
# 0
# repeat_num = 2, data_frame.shape[0] = 403200, data.shape[0] = 403200
# loop_path = loop\Metal\105-D\Intro\GuitarSub\08m_IQ HCP - [Kit 05] Guitar Loop 5 D3 105 BPM.wav
# data.shape[0] = 403200, bar8_sample = 806400
# 0
# repeat_num = 2, data_frame.shape[0] = 403200, data.shape[0] = 403200
# loop_path = loop\Metal\105-D\Intro\GuitarSub\08m_IQ HCP - [Kit 05] Guitar Loop 6 D1 105 BPM.wav
# data.shape[0] = 403200, bar8_sample = 806400
# 0
# repeat_num = 2, data_frame.shape[0] = 403200, data.shape[0] = 403200
# loop_path = loop\Metal\105-D\Intro\GuitarSub\08m_IQ HCP - [Kit 05] Guitar Loop 8 D1 105 BPM.wav
# data.shape[0] = 403200, bar8_sample = 806400
# 0
# repeat_num = 2, data_frame.shape[0] = 403200, data.shape[0] = 403200
# loop_path = loop\Metal\105-D\Intro\GuitarSub\08m_IQ HCP - [Kit 05] Guitar Loop 9 D1 105 BPM.wav
# data.shape[0] = 403200, bar8_sample = 806400
# 0
# repeat_num = 2, data_frame.shape[0] = 403200, data.shape[0] = 403200
# loop_path = loop\Metal\105-D\Sabi\Bass\08m_IQ HCP - [Kit 05] Bass Loop 1 D1 105 BPM.wav
# data.shape[0] = 364966, bar8_sample = 806400
# 38234
# repeat_num = 2, data_frame.shape[0] = 403200, data.shape[0] = 364966
# loop_path = loop\Metal\105-D\Sabi\Bass\08m_IQ HCP - [Kit 05] Bass Loop 2 D1 105 BPM.wav
# data.shape[0] = 364966, bar8_sample = 806400
# 38234
# repeat_num = 2, data_frame.shape[0] = 403200, data.shape[0] = 364966
# loop_path = loop\Metal\105-D\Sabi\Drum\08m_IQ HCP - [Kit 05] Drum Loop 1 105 BPM.wav
# data.shape[0] = 403200, bar8_sample = 806400
# 0
# repeat_num = 2, data_frame.shape[0] = 403200, data.shape[0] = 403200
# loop_path = loop\Metal\105-D\Sabi\Drum\08m_IQ HCP - [Kit 05] Drum Loop 2 105 BPM.wav
# data.shape[0] = 403200, bar8_sample = 806400
# 0
# repeat_num = 2, data_frame.shape[0] = 403200, data.shape[0] = 403200
# loop_path = loop\Metal\105-D\Sabi\Drum\08m_IQ HCP - [Kit 05] Drum Loop 3 105 BPM.wav
# data.shape[0] = 403200, bar8_sample = 806400
# 0
# repeat_num = 2, data_frame.shape[0] = 403200, data.shape[0] = 403200
# loop_path = loop\Metal\105-D\Sabi\Drum\08m_IQ HCP - [Kit 05] Drum Loop 4 105 BPM.wav
# data.shape[0] = 403200, bar8_sample = 806400
# 0
# repeat_num = 2, data_frame.shape[0] = 403200, data.shape[0] = 403200
# loop_path = loop\Metal\105-D\Sabi\GuitarMain\04m_IQ HCP - [Kit 05] Guitar Loop 7 D1 105 BPM.wav
# data.shape[0] = 201600, bar8_sample = 806400
# 0
# repeat_num = 4, data_frame.shape[0] = 201600, data.shape[0] = 201600
# loop_path = loop\Metal\105-D\Sabi\GuitarMain\08m_IQ HCP - [Kit 05] Guitar Loop 1 D1 105 BPM.wav
# data.shape[0] = 403200, bar8_sample = 806400
# 0
# repeat_num = 2, data_frame.shape[0] = 403200, data.shape[0] = 403200
# loop_path = loop\Metal\105-D\Sabi\GuitarMain\08m_IQ HCP - [Kit 05] Guitar Loop 2 D0 105 BPM.wav
# data.shape[0] = 403200, bar8_sample = 806400
# 0
# repeat_num = 2, data_frame.shape[0] = 403200, data.shape[0] = 403200
# loop_path = loop\Metal\105-D\Sabi\GuitarMain\08m_IQ HCP - [Kit 05] Guitar Loop 3 D3 105 BPM.wav
# data.shape[0] = 403200, bar8_sample = 806400
# 0
# repeat_num = 2, data_frame.shape[0] = 403200, data.shape[0] = 403200
# loop_path = loop\Metal\105-D\Sabi\GuitarMain\08m_IQ HCP - [Kit 05] Guitar Loop 4 D3 105 BPM.wav
# data.shape[0] = 403200, bar8_sample = 806400
# 0
# repeat_num = 2, data_frame.shape[0] = 403200, data.shape[0] = 403200
# loop_path = loop\Metal\105-D\Sabi\GuitarMain\08m_IQ HCP - [Kit 05] Guitar Loop 5 D3 105 BPM.wav
# data.shape[0] = 403200, bar8_sample = 806400
# 0
# repeat_num = 2, data_frame.shape[0] = 403200, data.shape[0] = 403200
# loop_path = loop\Metal\105-D\Sabi\GuitarMain\08m_IQ HCP - [Kit 05] Guitar Loop 6 D1 105 BPM.wav
# data.shape[0] = 403200, bar8_sample = 806400
# 0
# repeat_num = 2, data_frame.shape[0] = 403200, data.shape[0] = 403200
# loop_path = loop\Metal\105-D\Sabi\GuitarMain\08m_IQ HCP - [Kit 05] Guitar Loop 8 D1 105 BPM.wav
# data.shape[0] = 403200, bar8_sample = 806400
# 0
# repeat_num = 2, data_frame.shape[0] = 403200, data.shape[0] = 403200
# loop_path = loop\Metal\105-D\Sabi\GuitarMain\08m_IQ HCP - [Kit 05] Guitar Loop 9 D1 105 BPM.wav
# data.shape[0] = 403200, bar8_sample = 806400
# 0
# repeat_num = 2, data_frame.shape[0] = 403200, data.shape[0] = 403200
# loop_path = loop\Metal\105-D\Sabi\GuitarSub\04m_IQ HCP - [Kit 05] Guitar Loop 7 D1 105 BPM.wav
# data.shape[0] = 201600, bar8_sample = 806400
# 0
# repeat_num = 4, data_frame.shape[0] = 201600, data.shape[0] = 201600
# loop_path = loop\Metal\105-D\Sabi\GuitarSub\08m_IQ HCP - [Kit 05] Guitar Loop 1 D1 105 BPM.wav
# data.shape[0] = 403200, bar8_sample = 806400
# 0
# repeat_num = 2, data_frame.shape[0] = 403200, data.shape[0] = 403200
# loop_path = loop\Metal\105-D\Sabi\GuitarSub\08m_IQ HCP - [Kit 05] Guitar Loop 2 D0 105 BPM.wav
# data.shape[0] = 403200, bar8_sample = 806400
# 0
# repeat_num = 2, data_frame.shape[0] = 403200, data.shape[0] = 403200
# loop_path = loop\Metal\105-D\Sabi\GuitarSub\08m_IQ HCP - [Kit 05] Guitar Loop 3 D3 105 BPM.wav
# data.shape[0] = 403200, bar8_sample = 806400
# 0
# repeat_num = 2, data_frame.shape[0] = 403200, data.shape[0] = 403200
# loop_path = loop\Metal\105-D\Sabi\GuitarSub\08m_IQ HCP - [Kit 05] Guitar Loop 4 D3 105 BPM.wav
# data.shape[0] = 403200, bar8_sample = 806400
# 0
# repeat_num = 2, data_frame.shape[0] = 403200, data.shape[0] = 403200
# loop_path = loop\Metal\105-D\Sabi\GuitarSub\08m_IQ HCP - [Kit 05] Guitar Loop 5 D3 105 BPM.wav
# data.shape[0] = 403200, bar8_sample = 806400
# 0
# repeat_num = 2, data_frame.shape[0] = 403200, data.shape[0] = 403200
# loop_path = loop\Metal\105-D\Sabi\GuitarSub\08m_IQ HCP - [Kit 05] Guitar Loop 6 D1 105 BPM.wav
# data.shape[0] = 403200, bar8_sample = 806400
# 0
# repeat_num = 2, data_frame.shape[0] = 403200, data.shape[0] = 403200
# loop_path = loop\Metal\105-D\Sabi\GuitarSub\08m_IQ HCP - [Kit 05] Guitar Loop 8 D1 105 BPM.wav
# data.shape[0] = 403200, bar8_sample = 806400
# 0
# repeat_num = 2, data_frame.shape[0] = 403200, data.shape[0] = 403200
# loop_path = loop\Metal\105-D\Sabi\GuitarSub\08m_IQ HCP - [Kit 05] Guitar Loop 9 D1 105 BPM.wav
# data.shape[0] = 403200, bar8_sample = 806400
# 0
# repeat_num = 2, data_frame.shape[0] = 403200, data.shape[0] = 403200
# loop_path = loop\Vocalo\162-D\Amelo\Bass\04m_cool-bass_170bpm_A_minor_bpm170to162_KeyAmtoBm.wav
# data.shape[0] = 262014, bar8_sample = 522666
# -681
# repeat_num = 2, data_frame.shape[0] = 261333, data.shape[0] = 262014
# loop_path = loop\Vocalo\162-D\Amelo\Bass\04m_fast-fingers_120bpm_B_major_bpm120to162_KeyBtoD.wav
# data.shape[0] = 262014, bar8_sample = 522666
# -681
# repeat_num = 2, data_frame.shape[0] = 261333, data.shape[0] = 262014
# loop_path = loop\Vocalo\162-D\Amelo\Bass\04m_rock-bass-loop_125bpm_A#_major_bpm125to162_KeyA#toD.wav
# data.shape[0] = 261844, bar8_sample = 522666
# -511
# repeat_num = 2, data_frame.shape[0] = 261333, data.shape[0] = 261844
# loop_path = loop\Vocalo\162-D\Amelo\Bass\08m_fast-fingers_120bpm_B_major_bpm120to81_KeyBtoD.wav
# data.shape[0] = 523347, bar8_sample = 522666
# loop_path = loop\Vocalo\162-D\Amelo\Bass\08m_rock-bass-groove-bass-line_120bpm_B_minor_bpm120to162.wav
# data.shape[0] = 522837, bar8_sample = 522666
# loop_path = loop\Vocalo\162-D\Amelo\Drum\04m_yt1s.com - 120 BPM slow drum loop balladno copyright samples royaltyfree music_bpm120to162.wav
# data.shape[0] = 262014, bar8_sample = 522666
# -681
# repeat_num = 2, data_frame.shape[0] = 261333, data.shape[0] = 262014
# loop_path = loop\Vocalo\162-D\Amelo\Drum\04m_yt1s.com - 150 BPMロックドラムループ16beat著作権フリー練習用_bpm150to162.wav
# data.shape[0] = 261503, bar8_sample = 522666
# -170
# repeat_num = 2, data_frame.shape[0] = 261333, data.shape[0] = 261503
# loop_path = loop\Vocalo\162-D\Amelo\Drum\04m_yt1s.com - 160 BPMロックドラムループ　8ビートフリートラックドラム素材無料_bpm160to162.wav
# data.shape[0] = 261503, bar8_sample = 522666
# -170
# repeat_num = 2, data_frame.shape[0] = 261333, data.shape[0] = 261503
# loop_path = loop\Vocalo\162-D\Amelo\Drum\04m_yt1s.com - shuffle beat 160 bpm free drum loop Track No copyright_bpm160to162.wav
# data.shape[0] = 262184, bar8_sample = 522666
# -851
# repeat_num = 2, data_frame.shape[0] = 261333, data.shape[0] = 262184
# loop_path = loop\Vocalo\162-D\Amelo\Drum\08m_50_Best_Free_Drum_Loops-Drum_bpm170to162.wav
# data.shape[0] = 523007, bar8_sample = 522666
# loop_path = loop\Vocalo\162-D\Amelo\GuitarMain\08m_02 Electric Guitar PR1 02 - Guitar Rhythm 1 - 162 BPM - D.wav
# data.shape[0] = 522667, bar8_sample = 522666
# loop_path = loop\Vocalo\162-D\Amelo\GuitarMain\08m_03 Electric Guitar PR1 08 - Guitar 2 Double - 162 BPM - D.wav
# data.shape[0] = 522667, bar8_sample = 522666
# loop_path = loop\Vocalo\162-D\Amelo\GuitarMain\08m_04 Electric Guitar PR1 08 - Guitar 2 - 162 BPM - D.wav
# data.shape[0] = 522667, bar8_sample = 522666
# loop_path = loop\Vocalo\162-D\Amelo\GuitarMain\16m_02 Electric Guitar PR1 03 - Guitar Rhythm 1 - 162 BPM - D.wav
# data.shape[0] = 1045334, bar8_sample = 522666
# loop_path = loop\Vocalo\162-D\Amelo\GuitarSub\08m_01 Electric Guitar PR1 02 - Guitar Rhythm 1 DI - 162 BPM - D.wav
# data.shape[0] = 522667, bar8_sample = 522666
# loop_path = loop\Vocalo\162-D\Amelo\GuitarSub\08m_01 Electric Guitar PR1 08 - Guitar 2 DI - 162 BPM - D.wav
# data.shape[0] = 522667, bar8_sample = 522666
# loop_path = loop\Vocalo\162-D\Amelo\GuitarSub\08m_02 Electric Guitar PR1 08 - Guitar 2 Double  DI - 162 BPM - D.wav
# data.shape[0] = 522667, bar8_sample = 522666
# loop_path = loop\Vocalo\162-D\Amelo\GuitarSub\16m_01 Electric Guitar PR1 03 - Guitar Rhythm 1 DI - 162 BPM - D.wav
# data.shape[0] = 1045334, bar8_sample = 522666
# loop_path = loop\Vocalo\162-D\Bmelo\Bass\04m_cool-bass_170bpm_A_minor_bpm170to162_KeyAmtoBm.wav
# data.shape[0] = 262014, bar8_sample = 522666
# -681
# repeat_num = 2, data_frame.shape[0] = 261333, data.shape[0] = 262014
# loop_path = loop\Vocalo\162-D\Bmelo\Bass\04m_fast-fingers_120bpm_B_major_bpm120to162_KeyBtoD.wav
# data.shape[0] = 262014, bar8_sample = 522666
# -681
# repeat_num = 2, data_frame.shape[0] = 261333, data.shape[0] = 262014
# loop_path = loop\Vocalo\162-D\Bmelo\Bass\04m_rock-bass-loop_125bpm_A#_major_bpm125to162_KeyA#toD.wav
# data.shape[0] = 261844, bar8_sample = 522666
# -511
# repeat_num = 2, data_frame.shape[0] = 261333, data.shape[0] = 261844
# loop_path = loop\Vocalo\162-D\Bmelo\Bass\08m_fast-fingers_120bpm_B_major_bpm120to81_KeyBtoD.wav
# data.shape[0] = 523347, bar8_sample = 522666
# loop_path = loop\Vocalo\162-D\Bmelo\Bass\08m_rock-bass-groove-bass-line_120bpm_B_minor_bpm120to162.wav
# data.shape[0] = 522837, bar8_sample = 522666
# loop_path = loop\Vocalo\162-D\Bmelo\Drum\04m_yt1s.com - 120 BPM slow drum loop balladno copyright samples royaltyfree music_bpm120to162.wav
# data.shape[0] = 262014, bar8_sample = 522666
# -681
# repeat_num = 2, data_frame.shape[0] = 261333, data.shape[0] = 262014
# loop_path = loop\Vocalo\162-D\Bmelo\Drum\04m_yt1s.com - 150 BPMロックドラムループ16beat著作権フリー練習用_bpm150to162.wav
# data.shape[0] = 261503, bar8_sample = 522666
# -170
# repeat_num = 2, data_frame.shape[0] = 261333, data.shape[0] = 261503
# loop_path = loop\Vocalo\162-D\Bmelo\Drum\04m_yt1s.com - shuffle beat 160 bpm free drum loop Track No copyright_bpm160to162.wav
# data.shape[0] = 262184, bar8_sample = 522666
# -851
# repeat_num = 2, data_frame.shape[0] = 261333, data.shape[0] = 262184
# loop_path = loop\Vocalo\162-D\Bmelo\Drum\08m_50_Best_Free_Drum_Loops-Drum_170bpm_to_162bpm.wav
# data.shape[0] = 523007, bar8_sample = 522666
# loop_path = loop\Vocalo\162-D\Bmelo\GuitarMain\08m_06 Electric Guitar PR1 02 - Guitar Riff 1 - 162 BPM - D.wav
# data.shape[0] = 522667, bar8_sample = 522666
# loop_path = loop\Vocalo\162-D\Bmelo\GuitarMain\08m_06 Electric Guitar PR1 03 - Guitar Riff 1 - 162 BPM - D.wav
# data.shape[0] = 1045334, bar8_sample = 522666
# loop_path = loop\Vocalo\162-D\Bmelo\GuitarMain\08m_06 Electric Guitar PR1 08 - Guitar Rhythm 1 - 162 BPM - D.wav
# data.shape[0] = 522667, bar8_sample = 522666
# loop_path = loop\Vocalo\162-D\Bmelo\GuitarMain\16m_02 Electric Guitar PR1 04 - Guitar 2 - 162 BPM - D.wav
# data.shape[0] = 1045333, bar8_sample = 522666
# loop_path = loop\Vocalo\162-D\Bmelo\GuitarSub\08m_05 Electric Guitar PR1 02 - Guitar Riff 1 DI - 162 BPM - D.wav
# data.shape[0] = 522667, bar8_sample = 522666
# loop_path = loop\Vocalo\162-D\Bmelo\GuitarSub\08m_05 Electric Guitar PR1 03 - Guitar Riff 1 DI - 162 BPM - D.wav
# data.shape[0] = 1045334, bar8_sample = 522666
# loop_path = loop\Vocalo\162-D\Bmelo\GuitarSub\08m_05 Electric Guitar PR1 08 - Guitar Rhythm 1 DI - 162 BPM - D.wav
# data.shape[0] = 522667, bar8_sample = 522666
# loop_path = loop\Vocalo\162-D\Bmelo\GuitarSub\16m_01 Electric Guitar PR1 04 - Guitar 2 DI - 162 BPM - D.wav
# data.shape[0] = 1045333, bar8_sample = 522666
# loop_path = loop\Vocalo\162-D\Intro\Bass\04m_cool-bass_170bpm_A_minor_bpm170to162_KeyAmtoBm.wav
# data.shape[0] = 262014, bar8_sample = 522666
# -681
# repeat_num = 2, data_frame.shape[0] = 261333, data.shape[0] = 262014
# loop_path = loop\Vocalo\162-D\Intro\Bass\04m_fast-fingers_120bpm_B_major_bpm120to162_KeyBtoD.wav
# data.shape[0] = 262014, bar8_sample = 522666
# -681
# repeat_num = 2, data_frame.shape[0] = 261333, data.shape[0] = 262014
# loop_path = loop\Vocalo\162-D\Intro\Bass\04m_rock-bass-loop_125bpm_A#_major_bpm125to162_KeyA#toD.wav
# data.shape[0] = 261844, bar8_sample = 522666
# -511
# repeat_num = 2, data_frame.shape[0] = 261333, data.shape[0] = 261844
# loop_path = loop\Vocalo\162-D\Intro\Bass\08m_fast-fingers_120bpm_B_major_bpm120to81_KeyBtoD.wav
# data.shape[0] = 523347, bar8_sample = 522666
# loop_path = loop\Vocalo\162-D\Intro\Bass\08m_rock-bass-groove-bass-line_120bpm_B_minor_bpm120to162.wav
# data.shape[0] = 522837, bar8_sample = 522666
# loop_path = loop\Vocalo\162-D\Intro\Drum\04m_yt1s.com - 120 BPM slow drum loop balladno copyright samples royaltyfree music_bpm120to162.wav
# data.shape[0] = 262014, bar8_sample = 522666
# -681
# repeat_num = 2, data_frame.shape[0] = 261333, data.shape[0] = 262014
# loop_path = loop\Vocalo\162-D\Intro\Drum\04m_yt1s.com - 150 BPMロックドラムループ16beat著作権フリー練習用_bpm150to162.wav
# data.shape[0] = 261503, bar8_sample = 522666
# -170
# repeat_num = 2, data_frame.shape[0] = 261333, data.shape[0] = 261503
# loop_path = loop\Vocalo\162-D\Intro\Drum\04m_yt1s.com - 160 BPMロックドラムループ　8ビートフリートラックドラム素材無料_bpm160to162.wav
# data.shape[0] = 261503, bar8_sample = 522666
# -170
# repeat_num = 2, data_frame.shape[0] = 261333, data.shape[0] = 261503
# loop_path = loop\Vocalo\162-D\Intro\Drum\04m_yt1s.com - shuffle beat 160 bpm free drum loop Track No copyright_bpm160to162.wav
# data.shape[0] = 262184, bar8_sample = 522666
# -851
# repeat_num = 2, data_frame.shape[0] = 261333, data.shape[0] = 262184
# loop_path = loop\Vocalo\162-D\Intro\GuitarMain\08m_02 Electric Guitar PR1 01 - Guitar Rhythm 1 - 162 BPM - D.wav
# data.shape[0] = 522667, bar8_sample = 522666
# loop_path = loop\Vocalo\162-D\Intro\GuitarMain\18m_06 Electric Guitar PR1 04 - Guitar Rhythm 1 - 162 BPM - D.wav
# data.shape[0] = 1176000, bar8_sample = 522666
# loop_path = loop\Vocalo\162-D\Intro\GuitarSub\08m_01 Electric Guitar PR1 01 - Guitar Rhythm 1 DI - 162 BPM - D.wav
# data.shape[0] = 522667, bar8_sample = 522666
# loop_path = loop\Vocalo\162-D\Intro\GuitarSub\18m_05 Electric Guitar PR1 04 - Guitar Rhythm 1 DI - 162 BPM - D.wav
# data.shape[0] = 1176000, bar8_sample = 522666
# loop_path = loop\Vocalo\162-D\Sabi\Bass\04m_cool-bass_170bpm_A_minor_bpm170to162_KeyAmtoBm.wav
# data.shape[0] = 262014, bar8_sample = 522666
# -681
# repeat_num = 2, data_frame.shape[0] = 261333, data.shape[0] = 262014
# loop_path = loop\Vocalo\162-D\Sabi\Bass\04m_fast-fingers_120bpm_B_major_bpm120to162_KeyBtoD.wav
# data.shape[0] = 262014, bar8_sample = 522666
# -681
# repeat_num = 2, data_frame.shape[0] = 261333, data.shape[0] = 262014
# loop_path = loop\Vocalo\162-D\Sabi\Bass\04m_rock-bass-loop_125bpm_A#_major_bpm125to162_KeyA#toD.wav
# data.shape[0] = 261844, bar8_sample = 522666
# -511
# repeat_num = 2, data_frame.shape[0] = 261333, data.shape[0] = 261844
# loop_path = loop\Vocalo\162-D\Sabi\Bass\08m_fast-fingers_120bpm_B_major_bpm120to81_KeyBtoD.wav
# data.shape[0] = 523347, bar8_sample = 522666
# loop_path = loop\Vocalo\162-D\Sabi\Bass\08m_rock-bass-groove-bass-line_120bpm_B_minor_bpm120to162.wav
# data.shape[0] = 522837, bar8_sample = 522666
# loop_path = loop\Vocalo\162-D\Sabi\Drum\04m_yt1s.com - 120 BPM slow drum loop balladno copyright samples royaltyfree music_bpm120to162.wav
# data.shape[0] = 262014, bar8_sample = 522666
# -681
# repeat_num = 2, data_frame.shape[0] = 261333, data.shape[0] = 262014
# loop_path = loop\Vocalo\162-D\Sabi\Drum\04m_yt1s.com - 150 BPMロックドラムループ16beat著作権フリー練習用_bpm150to162.wav
# data.shape[0] = 261503, bar8_sample = 522666
# -170
# repeat_num = 2, data_frame.shape[0] = 261333, data.shape[0] = 261503
# loop_path = loop\Vocalo\162-D\Sabi\Drum\04m_yt1s.com - 160 BPMロックドラムループ　8ビートフリートラックドラム素材無料_bpm160to162.wav
# data.shape[0] = 261503, bar8_sample = 522666
# -170
# repeat_num = 2, data_frame.shape[0] = 261333, data.shape[0] = 261503
# loop_path = loop\Vocalo\162-D\Sabi\Drum\04m_yt1s.com - shuffle beat 160 bpm free drum loop Track No copyright_bpm160to162.wav
# data.shape[0] = 262184, bar8_sample = 522666
# -851
# repeat_num = 2, data_frame.shape[0] = 261333, data.shape[0] = 262184
# loop_path = loop\Vocalo\162-D\Sabi\GuitarSub\16m_03 Electric Guitar PR1 04 - Guitar 2 Double  DI - 162 BPM - D.wav
# data.shape[0] = 1176000, bar8_sample = 522666
# loop_path = loop\Vocalo\162-D\Sabi\GuitarSub\18m_05 Electric Guitar PR1 04 - Guitar Rhythm 1 DI - 162 BPM - D.wav
# data.shape[0] = 1176000, bar8_sample = 522666
# loop_path = loop\Vocalo\162-D\Sabi\GutiarMain\16m_04 Electric Guitar PR1 04 - Guitar 2 Double - 162 BPM - D.wav
# data.shape[0] = 1176000, bar8_sample = 522666
# loop_path = loop\Vocalo\162-D\Sabi\GutiarMain\18m_06 Electric Guitar PR1 04 - Guitar Rhythm 1 - 162 BPM - D.wav
# data.shape[0] = 1176000, bar8_sample = 522666

# %%
def fit_loop_8bar(bpm, loop_path, out_path):
    data,samplerate = sf.read(loop_path,always_2d=True)
    bar8_sec    = 60 / bpm * 4 * 8
    bar8_sample = int(bar8_sec * samplerate)
    print(f"data.shape[0] = {data.shape[0]}, bar8_sample = {bar8_sample}")
    # ループ素材が8小節を超えるの長さを持つとき
    if data.shape[0] > bar8_sample :
        data_cut = data[:bar8_sample]
    # ループ素材が8小節以下の長さを持つとき
    else:
        # 小節単位で繰り返す
        repeat_num = round(bar8_sample / data.shape[0])
        data_frame = np.zeros([int(bar8_sample / repeat_num), 2])
        print(data_frame.shape[0] - data.shape[0])
        print(f"repeat_num = {repeat_num}, data_frame.shape[0] = {data_frame.shape[0]}, data.shape[0] = {data.shape[0]}")
        if data_frame.shape[0] < data.shape[0] :
            data_frame = data[:int(bar8_sample / repeat_num)]
        else:
            data_frame[:data.shape[0]] = data
        data_cut = np.tile(data_frame,[repeat_num,1])

    sf.write(out_path,data_cut,samplerate)

def repeat_loop(loop_path,out_path,repeat_num=1):
    data,samplerate = sf.read(loop_path,always_2d=True)
    data_cut = np.tile(data,[repeat_num,1])
    sf.write(out_path,data_cut,samplerate)
